# %% [markdown]
# Use the proper datatypes when loading our dataset. Knowing datatypes will save space on the database server which in turn provides faster reads and writes. Furthermore, having proper datatypes will ensure that any errors in your data will be caught at insertion and your data can be queried the way you expect.
#
# The type_code field gives a numeric code representing the type of the data inside of the table. Unless one is used to work with Postgres for a long time, it is hard to memorize these codes and to know to which type they correspond. Thankfully, there is a special table in Postgres named pg_catalog.pg_type that contains the information about the data types. We are going to see in this screen how we can get the name of a data type given its type code.
#
# The decimal type works based on two parameters, the precision and the scale. The precision gives the maximum number of digits in total (before and after the decimal point). which is the maximum amount of digits before and/or after the decimal point. The scale specifies the maximum amount of digits after the decimal point. So, for instance, the number 23.5141 has a precision of 6 and a scale of 4. Integers can be considered to have a scale of zero.
#
# Using Postgres, it's better to use the text field for uncertain sizes and varchar(N) for ones you know the maximum length.
#
#
# Enumerated datatypes are useful in situations where a given column can only contain a predefined set of values<br/>
# Equivalent and shorter and more convenient syntax using :: for converting a datatype into another<br>
# ALTER TABLE table_name<br>
# ALTER COLUMN column_name TYPE enum_type_name<br>
# USING column_name::enum_type_name;<br>

# %% [markdown]
# # SQL Injections
#
# The ability of a user to be able to execute custom SQL by replacing values by SQL code and have it executed by the database server is known as a **SQL injection**.
#
# If a query is very long and has a lot of placeholders, positional arguments might be hard to read because we have to remember how many %s we have read so far to know to which position of the tuple it corresponds. The cursor.execute() method proposes and alternative way which uses a dictionary rather than a tuple to specify the values. Each placeholder is specified as %(key)s where key specifies a name for the value which is used as the key in the dictionary. Using this, order does not matter anymore, value are matched by keys.
#
# cur.execute("INSERT INTO users VALUES (%(id)s, %(email)s, %(name)s, %(address)s);", {<br>
#     'address': '124, Fake Street'<br>
#     'name': 'John', <br>
#     'id': 1000, <br>
#     'email': 'hello@dataquest.io', <br>
# })<br>

# %%
import psycopg2

# %%
conn = psycopg2.connect("dbname=Dataquest user=postgres password=123")

# %%
cur = conn.cursor()

# %%
cur.execute("SELECT * FROM users LIMIT 5")
cur.fetchall()
# Out:
# [(0,
#   'anna.carter@gmail.com',
#   'Anna Carter',
#   '27183 Craig Shore Suite 886 New Benjamin TN 92858'),
#  (1,
#   'joseph.kirby@yahoo.com',
#   'Joseph Kirby',
#   '3594 Fox Ford Apt. 192 West Kristen GA 22838-8977'),
#  (2,
#   'larry.cain@martinez.net',
#   'Larry Cain',
#   '58208 Cook Bypass West Benjaminfurt OH 25179'),
#  (3,
#   'johnathan.soto@yahoo.com',
#   'Johnathan Soto',
#   '68536 Avery Expressway Amberton PA 95197'),
#  (4,
#   'paula.acosta@yahoo.com',
#   'Paula Acosta',
#   '065 Kayla Alley Apt. 098 Walkerview NH 14274')]

# %%
conn.close()

# %%
def get_email(name):
    import psycopg2
    conn = psycopg2.connect("dbname=Dataquest user=postgres password=123")
    cur = conn.cursor()
    #create the query string using the format function
    query_string = "SELECT email FROM users WHERE name='" + name + "';"
    #execute the query
    cur.execute(query_string)
    res = cur.fetchall()
    conn.close()
    return res

# %%
all_emails = get_email("Joseph Kirby' OR 1 = 1; --")

# %%
all_emails
# Out:
# [('anna.carter@gmail.com',),
#  ('joseph.kirby@yahoo.com',),
#  ('larry.cain@martinez.net',),
#  ('johnathan.soto@yahoo.com',),
#  ('paula.acosta@yahoo.com',),
#  ('james.west@lam.com',),
#  ('tammy.hodges@nunez.info',),
#  ('travis.brown@jones.info',),
#  ('troy.baldwin@hotmail.com',),
#  ('mrs..amanda@hotmail.com',),
#  ('brian.williams@hotmail.com',),
#  ('michael.parks@hodges.com',),
#  ('john.hernandez@cooper-baker.net',),
#  ('monica.jones@olson.org',),
#  ('randy.carroll@wolf.info',),
#  ('holly.oliver@yahoo.com',),
#  ('tracey.love@hotmail.com',),
#  ('william.hayes@yahoo.com',),
#  ('christopher.ross@mcknight-mcguire.com',),
#  ('joshua.dominguez@richardson.com',),
#  ('stephanie.ho@gmail.com',),
#  ('gary.medina@hotmail.com',),
#  ('joann.weaver@yahoo.com',),
#  ('dr..robert@gmail.com',),
#  ('thomas.williams@hotmail.com',),
#  ('ashley.hudson@hotmail.com',),
#  ('charles.macdonald@yahoo.com',),
#  ('jonathan.haynes@gordon.info',),
#  ('megan.moran@johnson.com',),
#  ('daniel.holmes@king-scott.com',),
#  ('james.torres@bruce-greene.biz',),
#  ('eric.lutz@rush.com',),
#  ('christine.sanchez@hotmail.com',),
#  ('daniel.frazier@gmail.com',),
#  ('cory.chavez@yahoo.com',),
#  ('michelle.gonzales@gibson-avila.com',),
#  ('william.gomez@gmail.com',),
#  ('spencer.webb@mcbride.com',),
#  ('angela.howard@miller.net',),
#  ('vanessa.phillips@franklin-jacobs.info',),
#  ('melissa.cruz@hotmail.com',),
#  ('terry.holmes@yahoo.com',),
#  ('luke.nunez@patel-adams.info',),
#  ('kelly.moore@mendez.net',),
#  ('john.andrade@cooper.com',),
#  ('brandon.hanson@james-hicks.com',),
#  ('john.phillips@downs-pitts.biz',),
#  ('deborah.bennett@hall.com',),
#  ('brandon.waters@peck.biz',),
#  ('jared.lee@yahoo.com',),
#  ('michelle.mendoza@porter.com',),
#  ('jonathan.mitchell@gmail.com',),
#  ('mrs..melissa@hotmail.com',),
#  ('james.nolan@gmail.com',),
#  ('jacqueline.mclaughlin@ford-copeland.com',),
#  ('molly.torres@hotmail.com',),
#  ('connor.adams@yahoo.com',),
#  ('eric.smith@gmail.com',),
#  ('michael.cruz@shaw.info',),
#  ('lisa.stevenson@hotmail.com',),
#  ('zachary.spears@guzman.net',),
#  ('austin.mitchell@fowler-bishop.com',),
#  ('heather.patrick@pope.biz',),
#  ('jennifer.torres@gmail.com',),
#  ('victor.kramer@yahoo.com',),
#  ('roberto.jackson@yahoo.com',),
#  ('phillip.harris@suarez.com',),
#  ('christina.jenkins@hotmail.com',),
#  ('david.martin@hotmail.com',),
#  ('kenneth.alexander@hotmail.com',),
#  ('stephen.moore@green.com',),
#  ('andrew.williams@jones.com',),
#  ('nicholas.harding@cervantes-martinez.com',),
#  ('ryan.higgins@hotmail.com',),
#  ('deborah.clements@crane.com',),
#  ('preston.morales@sullivan.com',),
#  ('ryan.phillips@davis.org',),
#  ('destiny.sullivan@stone.com',),
#  ('nancy.parker@gmail.com',),
#  ('steven.black@soto.biz',),
#  ('priscilla.davis@rodriguez-lamb.com',),
#  ('jacob.curtis@murray.com',),
#  ('jenny.cook@gmail.com',),
#  ('jennifer.diaz@yahoo.com',),
#  ('angel.pena@burton.com',),
#  ('laura.martinez@hotmail.com',),
#  ('douglas.miller@williams.com',),
#  ('stephen.riddle@smith.com',),
#  ('james.johnson@hughes.net',),
#  ('eric.williams@burns.com',),
#  ('edward.johnson@hotmail.com',),
#  ('nicole.davis@yahoo.com',),
#  ('robert.robertson@hotmail.com',),
#  ('frederick.schwartz@perkins.info',),
#  ('louis.reynolds@yahoo.com',),
#  ('lance.yang@yahoo.com',),
#  ('david.fletcher@brown.org',),
#  ('angela.saunders@yahoo.com',),
#  ('mike.kane@sullivan-berg.info',),
#  ('john.smith@gmail.com',),
#  ('mrs..crystal@aguilar.com',),
#  ('alyssa.brown@carr-mccall.com',),
#  ('stephanie.poole@woodward-lewis.biz',),
#  ('anthony.phillips@yahoo.com',),
#  ('jimmy.morris@gmail.com',),
#  ('tiffany.rodriguez@scott-weiss.biz',),
#  ('andrea.bennett@carroll-cantrell.com',),
#  ('carolyn.combs@garcia-davis.com',),
#  ('billy.rojas@hotmail.com',),
#  ('jonathan.hansen@hotmail.com',),
#  ('nicole.parker@gmail.com',),
#  ('tara.harrell@bentley.net',),
#  ('nicholas.johnson@schmidt.com',),
#  ('janet.wallace@yahoo.com',),
#  ('monica.clark@hotmail.com',),
#  ('william.burke@perry-zavala.com',),
#  ('amanda.torres@myers.com',),
#  ('kristin.smith@cobb.biz',),
#  ('dr..michele@chavez-combs.info',),
#  ('wayne.parker@thompson.org',),
#  ('james.scott@holt-phillips.com',),
#  ('kevin.daniels@hotmail.com',),
#  ('jacob.valencia@yahoo.com',),
#  ('jennifer.perkins@gmail.com',),
#  ('deborah.lambert@payne-ayers.info',),
#  ('diana.rojas@yahoo.com',),
#  ('daniel.brooks@hotmail.com',),
#  ('valerie.salazar@yahoo.com',),
#  ('rachel.brown@yahoo.com',),
#  ('david.jimenez@yahoo.com',),
#  ('holly.cooper@yahoo.com',),
#  ('barbara.lewis@carr.com',),
#  ('brian.perry@gmail.com',),
#  ('michael.scott@henderson-campos.com',),
#  ('kevin.hughes@singh-hart.com',),
#  ('cathy.silva@hotmail.com',),
#  ('mr..kyle@spencer.info',),
#  ('lisa.snow@hotmail.com',),
#  ('hannah.jackson@fisher.com',),
#  ('gary.livingston@nguyen-smith.com',),
#  ('christopher.gibbs@hotmail.com',),
#  ('thomas.sandoval@gmail.com',),
#  ('dr..teresa@guzman.com',),
#  ('christopher.mckenzie@baker.com',),
#  ('elizabeth.smith@yahoo.com',),
#  ('tammy.pierce@lowery.com',),
#  ('joseph.dixon@gmail.com',),
#  ('jeffrey.ruiz@booker-leonard.biz',),
#  ('ashley.henson@gmail.com',),
#  ('linda.henderson@gmail.com',),
#  ('jeremy.wilson@edwards-stuart.com',),
#  ('nicholas.clements@hotmail.com',),
#  ('raymond.zhang@hotmail.com',),
#  ('douglas.singh@nichols.biz',),
#  ('alec.arnold@yahoo.com',),
#  ('scott.adams@yahoo.com',),
#  ('samantha.wise@mcdonald.com',),
#  ('mary.peck@yahoo.com',),
#  ('rodney.robinson@gmail.com',),
#  ('stephen.barton@yahoo.com',),
#  ('kathleen.johnson@hotmail.com',),
#  ('alexander.hart@yahoo.com',),
#  ('amber.fox@hotmail.com',),
#  ('dr..francisco@hotmail.com',),
#  ('samuel.sawyer@yahoo.com',),
#  ('amanda.hansen@hotmail.com',),
#  ('brian.glass@yahoo.com',),
#  ('julie.smith@winters.com',),
#  ('kristina.sanchez@keller.info',),
#  ('megan.barrett@adkins-mathews.com',),
#  ('caroline.fox@gmail.com',),
#  ('amy.sawyer@yahoo.com',),
#  ('mark.turner@yahoo.com',),
#  ('susan.soto@martinez-summers.com',),
#  ('renee.maynard@yahoo.com',),
#  ('kimberly.cunningham@hotmail.com',),
#  ('robert.matthews@yahoo.com',),
#  ('courtney.jenkins@daniels.com',),
#  ('gregory.gomez@yahoo.com',),
#  ('rachel.ellison@yahoo.com',),
#  ('brianna.klein@harper-taylor.org',),
#  ('andre.mitchell@hotmail.com',),
#  ('allison.miranda@torres-vasquez.net',),
#  ('megan.quinn@yahoo.com',),
#  ('laura.wells@yahoo.com',),
#  ('christopher.romero@hotmail.com',),
#  ('vanessa.campbell@richardson.com',),
#  ('diana.rhodes@evans.net',),
#  ('charles.williams@gmail.com',),
#  ('gregory.savage@galvan.net',),
#  ('jamie.alvarado@bell-murray.info',),
#  ('lauren.gutierrez@smith-hill.com',),
#  ('donna.owen@chandler.com',),
#  ('miguel.dixon@jackson.com',),
#  ('omar.edwards@mcdonald.com',),
#  ('shelley.flores@harrington.com',),
#  ('holly.alvarez@yahoo.com',),
#  ('david.rodriguez@yahoo.com',),
#  ('angelica.clark@hotmail.com',),
#  ('ashley.macdonald@hotmail.com',),
#  ('william.hill@gmail.com',),
#  ('john.franklin@hotmail.com',),
#  ('jillian.ingram@yahoo.com',),
#  ('christopher.carter@brooks.com',),
#  ('susan.navarro@gmail.com',),
#  ('mariah.cobb@gmail.com',),
#  ('william.blanchard@gmail.com',),
#  ('morgan.gonzalez@hotmail.com',),
#  ('kelly.gonzalez@bradford-yoder.com',),
#  ('jacqueline.griffith@gmail.com',),
#  ('traci.ramirez@wallace.com',),
#  ('gina.king@deleon.com',),
#  ('tammy.contreras@gmail.com',),
#  ('christopher.murphy@yahoo.com',),
#  ('melanie.dickson@yahoo.com',),
#  ('laurie.hall@gmail.com',),
#  ('amanda.smith@hotmail.com',),
#  ('eric.powell@perry.com',),
#  ('dawn.miller@hunt.com',),
#  ('ashley.martinez@gmail.com',),
#  ('larry.perez@gmail.com',),
#  ('christina.adams@graham.com',),
#  ('john.reyes@benitez-jenkins.com',),
#  ('calvin.williams@yahoo.com',),
#  ('kathryn.perry@gmail.com',),
#  ('nicole.roth@yahoo.com',),
#  ('vickie.novak@reynolds-larson.biz',),
#  ('felicia.moran@hotmail.com',),
#  ('christopher.williams@potts.com',),
#  ('roy.knight@freeman-hart.net',),
#  ('oscar.king@yahoo.com',),
#  ('samantha.torres@burns-chandler.net',),
#  ('michael.nolan@weaver.com',),
#  ('jennifer.mack@yahoo.com',),
#  ('james.allen@gmail.com',),
#  ('tina.jacobson@wilson.com',),
#  ('rhonda.ritter@hotmail.com',),
#  ('jonathan.perry@hotmail.com',),
#  ('melissa.paul@weaver-nelson.com',),
#  ('brian.hill@gmail.com',),
#  ('deborah.higgins@hotmail.com',),
#  ('kyle.davis@snyder-hammond.org',),
#  ('melissa.russell@hotmail.com',),
#  ('brittany.holmes@hotmail.com',),
#  ('gavin.may@ballard-burton.com',),
#  ('robert.smith@bowman.com',),
#  ('edward.anderson@hotmail.com',),
#  ('matthew.mejia@hotmail.com',),
#  ('alison.davis@adams-santiago.com',),
#  ('jonathan.miller@ayala.com',),
#  ('dale.meyer@white.net',),
#  ('luke.ayala@yahoo.com',),
#  ('sara.hartman@bates.com',),
#  ('kimberly.banks@hotmail.com',),
#  ('janet.ortega@yahoo.com',),
#  ('tyler.nelson@payne.info',),
#  ('heather.blake@gmail.com',),
#  ('alyssa.scott@yahoo.com',),
#  ('margaret.miranda@williams.com',),
#  ('maria.nelson@yahoo.com',),
#  ('cindy.maxwell@cruz-hoffman.com',),
#  ('john.watson@hotmail.com',),
#  ('timothy.gonzalez@simpson.info',),
#  ('james.phillips@henderson.com',),
#  ('brandon.wilson@hotmail.com',),
#  ('kristen.johnson@donaldson.net',),
#  ('juan.flores@gmail.com',),
#  ('andrew.davila@morales-fernandez.com',),
#  ('brittany.burke@french.com',),
#  ('clayton.kelley@king.com',),
#  ('hannah.mitchell@yahoo.com',),
#  ('joanna.sparks@deleon.com',),
#  ('tara.hodges@yahoo.com',),
#  ('lynn.thompson@carson.com',),
#  ('jeremy.wallace@hotmail.com',),
#  ('jose.alvarez@gmail.com',),
#  ('autumn.hernandez@jimenez.com',),
#  ('kimberly.jefferson@hotmail.com',),
#  ('carrie.reid@mcdonald.com',),
#  ('joshua.carpenter@yahoo.com',),
#  ('jesus.hardin@smith-perkins.org',),
#  ('aaron.hill@scott.com',),
#  ('peter.sullivan@yahoo.com',),
#  ('craig.cervantes@yahoo.com',),
#  ('kimberly.avery@mendez.info',),
#  ('mallory.parrish@hotmail.com',),
#  ('brian.reed@williams.net',),
#  ('daniel.moore@harvey-petty.org',),
#  ('misty.huffman@yahoo.com',),
#  ('diane.chapman@watson.info',),
#  ('robert.archer@moore.com',),
#  ('alice.terry@wilson.com',),
#  ('aaron.rocha@gmail.com',),
#  ('leslie.lyons@page-parker.com',),
#  ('louis.boyd@hughes-jones.com',),
#  ('jessica.barber@hotmail.com',),
#  ('james.hernandez@hotmail.com',),
#  ('nathan.phillips@hotmail.com',),
#  ('susan.thompson@wong.biz',),
#  ('hunter.riley@bailey.com',),
#  ('sarah.steele@gmail.com',),
#  ('cheryl.khan@hotmail.com',),
#  ('thomas.lewis@hotmail.com',),
#  ('john.price@smith.com',),
#  ('dustin.rodriguez@yahoo.com',),
#  ('erica.kennedy@gmail.com',),
#  ('eric.cannon@dillon-buchanan.com',),
#  ('stephanie.parrish@gmail.com',),
#  ('robert.doyle@thornton.com',),
#  ('ashley.ramos@smith.org',),
#  ('gregory.jones@hotmail.com',),
#  ('heidi.ingram@hotmail.com',),
#  ('michael.norton@watson-diaz.com',),
#  ('casey.gutierrez@gmail.com',),
#  ('april.norris@yahoo.com',),
#  ('kimberly.kelley@white-medina.com',),
#  ('ashley.bautista@gmail.com',),
#  ('jenna.stevens@phillips.com',),
#  ('christine.tran@gmail.com',),
#  ('dorothy.parker@gmail.com',),
#  ('alejandra.ramos@griffin.com',),
#  ('sean.salazar@gmail.com',),
#  ('kara.glenn@beasley.org',),
#  ('robert.beck@hotmail.com',),
#  ('margaret.baker@gmail.com',),
#  ('raymond.crawford@phillips-casey.com',),
#  ('brenda.huerta@lloyd.org',),
#  ('cody.lee@hotmail.com',),
#  ('julie.bennett@gmail.com',),
#  ('shannon.brown@gmail.com',),
#  ('william.preston@moore-henderson.com',),
#  ('bridget.gardner@yahoo.com',),
#  ('christina.romero@gmail.com',),
#  ('laura.meza@wong.com',),
#  ('johnny.conway@perez.com',),
#  ('claudia.alvarado@yahoo.com',),
#  ('devin.gardner@miller-castillo.com',),
#  ('kevin.robinson@hotmail.com',),
#  ('carmen.harper@hotmail.com',),
#  ('tyler.willis@hotmail.com',),
#  ('stephanie.williams@white.biz',),
#  ('brittany.gray@hotmail.com',),
#  ('janice.campos@obrien-young.info',),
#  ('denise.conley@cervantes.info',),
#  ('lisa.hopkins@hotmail.com',),
#  ('jennifer.smith@gmail.com',),
#  ('karen.smith@yahoo.com',),
#  ('brad.bass@gmail.com',),
#  ('gregory.miller@hotmail.com',),
#  ('valerie.branch@miller.com',),
#  ('brandi.stewart@yahoo.com',),
#  ('taylor.vazquez@gmail.com',),
#  ('anthony.smith@schmidt.com',),
#  ('bryce.fowler@hotmail.com',),
#  ('brenda.jones@gmail.com',),
#  ('regina.dixon@gonzales-rivera.net',),
#  ('evelyn.travis@ware.com',),
#  ('christopher.wood@hotmail.com',),
#  ('christine.hunt@gmail.com',),
#  ('derrick.long@clark.info',),
#  ('michael.harmon@hotmail.com',),
#  ('courtney.osborne@franklin.net',),
#  ('alexander.parsons@hotmail.com',),
#  ('jennifer.reyes@yahoo.com',),
#  ('brenda.matthews@smith.com',),
#  ('summer.williams@gmail.com',),
#  ('sarah.evans@yahoo.com',),
#  ('mrs..andrea@heath.com',),
#  ('kirsten.ross@king.com',),
#  ('dakota.harris@greer-martinez.com',),
#  ('christopher.cervantes@gmail.com',),
#  ('kayla.little@johnson.com',),
#  ('tracy.hicks@bowen.net',),
#  ('mary.pruitt@baird-gregory.info',),
#  ('caitlyn.white@preston.info',),
#  ('ashley.bowman@moore.com',),
#  ('casey.boyd@english-nelson.biz',),
#  ('kiara.gamble@moses.com',),
#  ('elizabeth.kelly@hotmail.com',),
#  ('elizabeth.fox@ali-brown.com',),
#  ('david.martinez@yahoo.com',),
#  ('linda.wiley@hotmail.com',),
#  ('thomas.mckee@yahoo.com',),
#  ('paul.shields@bowers.org',),
#  ('mary.coleman@yahoo.com',),
#  ('martha.burke@russell.com',),
#  ('nathan.ortega@cobb.net',),
#  ('madison.lutz@yahoo.com',),
#  ('joseph.moore@gmail.com',),
#  ('jason.schmitt@barr.biz',),
#  ('erik.bailey@gmail.com',),
#  ('karen.garza@gmail.com',),
#  ('kim.carroll@yahoo.com',),
#  ('sharon.daniels@wilson.info',),
#  ('leonard.stout@hotmail.com',),
#  ('anthony.madden@gmail.com',),
#  ('sarah.grimes@yahoo.com',),
#  ('barbara.barber@fuller.com',),
#  ('jay.johnson@mcconnell.com',),
#  ('joseph.torres@gmail.com',),
#  ('lisa.bauer@gmail.com',),
#  ('julie.collier@wagner.com',),
#  ('michael.page@gmail.com',),
#  ('glenda.crawford@salinas.com',),
#  ('melissa.avila@smith-moran.com',),
#  ('brett.anderson@larson.biz',),
#  ('mary.howell@gmail.com',),
#  ('kellie.larson@gonzalez.com',),
#  ('melissa.benson@hotmail.com',),
#  ('veronica.farrell@wilkerson.com',),
#  ('eric.pena@boone.com',),
#  ('cassandra.roman@yahoo.com',),
#  ('ms..jamie@gmail.com',),
#  ('cheryl.weber@padilla-mcgrath.com',),
#  ('cynthia.nolan@davis-ruiz.com',),
#  ('julia.anderson@yahoo.com',),
#  ('angela.cohen@yahoo.com',),
#  ('jade.smith@williams.net',),
#  ('morgan.daniels@gmail.com',),
#  ('denise.brown@williams.com',),
#  ('david.garcia@ford.biz',),
#  ('james.burns@yahoo.com',),
#  ('albert.goodman@gmail.com',),
#  ('shelley.sanchez@hunter.com',),
#  ('sarah.schneider@yahoo.com',),
#  ('joshua.savage@hotmail.com',),
#  ('brian.watson@rose-brown.biz',),
#  ('marie.martin@davis-jordan.com',),
#  ('gina.taylor@delgado.com',),
#  ('maria.white@yahoo.com',),
#  ('paula.mcdowell@carr.com',),
#  ('david.bishop@yahoo.com',),
#  ('jamie.knox@gray-douglas.com',),
#  ('vincent.robertson@smith-schneider.com',),
#  ('vincent.ford@davis.com',),
#  ('todd.medina@shepherd.com',),
#  ('nicholas.walker@hotmail.com',),
#  ('patrick.hill@flores-stewart.biz',),
#  ('david.grant@le-hodges.net',),
#  ('mr..john@williams-perry.org',),
#  ('victoria.vazquez@brown-bailey.com',),
#  ('bradley.ramos@thornton-fields.net',),
#  ('craig.knight@gmail.com',),
#  ('clifford.martinez@macias.info',),
#  ('leon.mcdonald@gmail.com',),
#  ('amy.kim@guzman.com',),
#  ('angela.horton@gmail.com',),
#  ('sheryl.whitaker@lee.com',),
#  ('doris.little@yahoo.com',),
#  ('tina.collins@hotmail.com',),
#  ('frederick.thompson@garza-smith.info',),
#  ('jamie.torres@robinson.com',),
#  ('timothy.cannon@gmail.com',),
#  ('james.parker@yahoo.com',),
#  ('thomas.ruiz@gmail.com',),
#  ('david.powell@hotmail.com',),
#  ('cindy.roman@tate.org',),
#  ('darrell.alvarado@gmail.com',),
#  ('philip.newman@gmail.com',),
#  ('sherri.frederick@osborn.com',),
#  ('zachary.cohen@smith.com',),
#  ('jordan.hopkins@mills.com',),
#  ('mark.olsen@brown-hurley.org',),
#  ('bobby.bell@gmail.com',),
#  ('tracy.freeman@kelly-castillo.net',),
#  ('richard.smith@gmail.com',),
#  ('lindsay.payne@vasquez.com',),
#  ('tanner.alvarez@perez-martinez.com',),
#  ('leah.johnson@yahoo.com',),
#  ('jacob.vargas@matthews-holmes.net',),
#  ('linda.moon@hotmail.com',),
#  ('nichole.wiggins@stone.net',),
#  ('jessica.owens@yahoo.com',),
#  ('teresa.huerta@hotmail.com',),
#  ('monica.rivera@hotmail.com',),
#  ('grant.boyd@yahoo.com',),
#  ('julie.burns@hotmail.com',),
#  ('aaron.ramos@lindsey.com',),
#  ('gordon.walker@malone-gregory.com',),
#  ('susan.townsend@richards.com',),
#  ('hannah.miller@yahoo.com',),
#  ('terry.ortega@kramer-blair.net',),
#  ('jackie.mcconnell@sharp.com',),
#  ('kayla.cantu@calhoun-may.com',),
#  ('sabrina.thompson@hotmail.com',),
#  ('daniel.rosales@scott-perry.com',),
#  ('james.fowler@hotmail.com',),
#  ('brittany.nolan@martinez.org',),
#  ('brandy.thompson@graham-todd.biz',),
#  ('julia.rodriguez@hotmail.com',),
#  ('melissa.wells@hotmail.com',),
#  ('jeffery.perez@yahoo.com',),
#  ('julia.jenkins@gmail.com',),
#  ('hannah.travis@hotmail.com',),
#  ('susan.craig@hotmail.com',),
#  ('amy.cantu@hotmail.com',),
#  ('annette.davidson@yahoo.com',),
#  ('brenda.price@gmail.com',),
#  ('lawrence.mathews@daniels-morrison.biz',),
#  ('ryan.taylor@hotmail.com',),
#  ('anthony.walker@gmail.com',),
#  ('joseph.martin@yahoo.com',),
#  ('michael.barnes@cochran.net',),
#  ('erica.oneill@sutton-rodriguez.com',),
#  ('sherry.elliott@ross.com',),
#  ('tammy.johnston@garcia.info',),
#  ('andrew.hess@gmail.com',),
#  ('michelle.moore@hotmail.com',),
#  ('paul.jackson@gmail.com',),
#  ('amanda.ramos@morgan.com',),
#  ('bethany.gonzales@hotmail.com',),
#  ('jose.garcia@ellis-diaz.com',),
#  ('matthew.baker@yahoo.com',),
#  ('brandi.parker@gmail.com',),
#  ('ashley.thompson@smith-solis.biz',),
#  ('rodney.walker@walker-dennis.com',),
#  ('maria.lopez@yahoo.com',),
#  ('robert.boyd@frank.com',),
#  ('diane.rodriguez@hotmail.com',),
#  ('angela.smith@yahoo.com',),
#  ('justin.long@harris.biz',),
#  ('tony.cross@gmail.com',),
#  ('michael.porter@hotmail.com',),
#  ('ruben.king@keller.com',),
#  ('gregg.clark@hotmail.com',),
#  ('ellen.morris@gmail.com',),
#  ('denise.osborne@yahoo.com',),
#  ('robert.fowler@leonard.com',),
#  ('scott.martin@yahoo.com',),
#  ('jason.marshall@hotmail.com',),
#  ('laura.garcia@bryant.com',),
#  ('angela.mcclure@moran.com',),
#  ('james.stokes@santiago-gutierrez.com',),
#  ('mr..jeffrey@yahoo.com',),
#  ('jennifer.miller@fisher.com',),
#  ('jennifer.obrien@stout-kelly.net',),
#  ('michael.marsh@yahoo.com',),
#  ('lance.baker@norris.info',),
#  ('teresa.ramsey@cherry.org',),
#  ('kellie.herrera@gmail.com',),
#  ('roy.diaz@jackson.com',),
#  ('alan.hanson@gmail.com',),
#  ('hannah.garcia@george.com',),
#  ('michael.morris@rivera.info',),
#  ('joseph.griffin@ross-hawkins.net',),
#  ('emily.matthews@melton.biz',),
#  ('george.jenkins@hotmail.com',),
#  ('tammy.henderson@yahoo.com',),
#  ('cynthia.jefferson@yahoo.com',),
#  ('catherine.davis@hotmail.com',),
#  ('ryan.johnson@gmail.com',),
#  ('nicole.davis@yahoo.com',),
#  ('katherine.snyder@smith.net',),
#  ('anthony.walters@gmail.com',),
#  ('laura.newman@hotmail.com',),
#  ('jeff.white@moore-day.com',),
#  ('shawn.curry@richardson-cross.com',),
#  ('scott.taylor@oneal.biz',),
#  ('tyler.johns@obrien.com',),
#  ('mrs..laura@gmail.com',),
#  ('courtney.conner@gmail.com',),
#  ('jennifer.phelps@jackson.com',),
#  ('leslie.bailey@richards-mcpherson.com',),
#  ('christopher.huff@gmail.com',),
#  ('brian.hernandez@gmail.com',),
#  ('amy.soto@meza-lara.com',),
#  ('linda.chan@delacruz.com',),
#  ('joseph.mullins@ramirez.info',),
#  ('edward.mitchell@cook.com',),
#  ('jeremy.santos@oliver.net',),
#  ('matthew.thompson@dixon-hernandez.com',),
#  ('michelle.pitts@webb-black.org',),
#  ('joseph.smith@gmail.com',),
#  ('brandon.williams@gmail.com',),
#  ('edward.hoffman@gmail.com',),
#  ('linda.bradford@hunter.com',),
#  ('robert.schwartz@yahoo.com',),
#  ('david.hansen@wilson-rice.info',),
#  ('stephanie.miller@mills-odonnell.net',),
#  ('kelly.miller@yahoo.com',),
#  ('randy.santiago@miller.org',),
#  ('susan.simmons@moore.com',),
#  ('melissa.french@gmail.com',),
#  ('paul.owens@brewer.com',),
#  ('crystal.perez@gmail.com',),
#  ('cheyenne.velazquez@yahoo.com',),
#  ('calvin.ochoa@yahoo.com',),
#  ('roberto.brown@hotmail.com',),
#  ('jesus.greene@gmail.com',),
#  ('jonathan.martinez@rodriguez.net',),
#  ('tony.king@mendoza-armstrong.com',),
#  ('james.mcclain@yahoo.com',),
#  ('michelle.campbell@hotmail.com',),
#  ('jonathan.davis@ferguson.com',),
#  ('isaac.mullins@yahoo.com',),
#  ('jennifer.pearson@duffy.org',),
#  ('teresa.harris@yahoo.com',),
#  ('lisa.wright@yahoo.com',),
#  ('elizabeth.sweeney@scott.com',),
#  ('jeffrey.kent@matthews.biz',),
#  ('anthony.nelson@yahoo.com',),
#  ('taylor.steele@miller-brown.com',),
#  ('hayden.snyder@gmail.com',),
#  ('kevin.armstrong@davis.net',),
#  ('joshua.allen@cruz.biz',),
#  ('gail.bird@yahoo.com',),
#  ('christina.hill@hotmail.com',),
#  ('paul.smith@hotmail.com',),
#  ('jeffrey.hernandez@yahoo.com',),
#  ('tiffany.clark@brown.net',),
#  ('trevor.moore@carter.com',),
#  ('chase.stanley@gmail.com',),
#  ('robert.payne@lopez-small.org',),
#  ('emily.davis@yahoo.com',),
#  ('brandon.johnson@gmail.com',),
#  ('michele.williams@hotmail.com',),
#  ('natalie.curtis@sexton.com',),
#  ('taylor.stewart@williams-king.com',),
#  ('jimmy.robertson@sanchez-ward.com',),
#  ('jesse.hayes@hotmail.com',),
#  ('marvin.copeland@hotmail.com',),
#  ('maureen.bowman@yahoo.com',),
#  ('bruce.rasmussen@gmail.com',),
#  ('melanie.carlson@gonzalez.org',),
#  ('dwayne.lindsey@chavez.com',),
#  ('ariel.hernandez@gmail.com',),
#  ('paul.carey@guzman.biz',),
#  ('cody.burgess@hotmail.com',),
#  ('tanner.lewis@yahoo.com',),
#  ('penny.nguyen@hotmail.com',),
#  ('patrick.rodriguez@mendoza.com',),
#  ('bobby.chan@hotmail.com',),
#  ('dale.johnson@henderson.com',),
#  ('caitlin.collins@yahoo.com',),
#  ('richard.allison@adams-mcguire.com',),
#  ('lauren.carter@strong.org',),
#  ('joseph.stanton@wilson-griffin.com',),
#  ('scott.jones@yahoo.com',),
#  ('derek.hicks@hotmail.com',),
#  ('lauren.turner@rose-thomas.com',),
#  ('thomas.byrd@gmail.com',),
#  ('caleb.jones@gmail.com',),
#  ('ronald.knight@stone-anderson.org',),
#  ('ryan.clark@roberts-brewer.com',),
#  ('mary.kane@hotmail.com',),
#  ('matthew.morgan@wu.com',),
#  ('amanda.gill@gmail.com',),
#  ('jennifer.nguyen@perkins.org',),
#  ('jacqueline.jones@gmail.com',),
#  ('julia.arroyo@kim.com',),
#  ('laura.garcia@gmail.com',),
#  ('ashley.greene@freeman.org',),
#  ('edward.simpson@hotmail.com',),
#  ('thomas.miller@wilson-jacobs.com',),
#  ('crystal.spears@yahoo.com',),
#  ('laura.irwin@martinez-brown.com',),
#  ('cheryl.mills@hotmail.com',),
#  ('michael.joyce@gmail.com',),
#  ('brett.bush@garcia.com',),
#  ('kyle.rodriguez@hotmail.com',),
#  ('jessica.hicks@yahoo.com',),
#  ('grace.cooper@robbins.com',),
#  ('jennifer.smith@hotmail.com',),
#  ('jessica.smith@yahoo.com',),
#  ('emma.stein@yahoo.com',),
#  ('rebecca.west@yahoo.com',),
#  ('annette.flores@mcclure.com',),
#  ('jonathan.chavez@berger.info',),
#  ('courtney.dickerson@gmail.com',),
#  ('taylor.durham@horton.info',),
#  ('johnny.benson@garcia.com',),
#  ('raven.garcia@hotmail.com',),
#  ('jennifer.peterson@gmail.com',),
#  ('kathleen.buchanan@yahoo.com',),
#  ('david.schmidt@yahoo.com',),
#  ('donald.gomez@humphrey.org',),
#  ('brent.mitchell@harris.com',),
#  ('carlos.brooks@yahoo.com',),
#  ('alexis.sweeney@gmail.com',),
#  ('jessica.miller@ayers.biz',),
#  ('teresa.jones@yahoo.com',),
#  ('philip.whitney@yahoo.com',),
#  ('stacy.moody@yahoo.com',),
#  ('elizabeth.sutton@ortiz-howe.net',),
#  ('vincent.stevens@hernandez-hernandez.com',),
#  ('pamela.wagner@rios-drake.com',),
#  ('randy.duncan@mejia.com',),
#  ('richard.romero@wood.com',),
#  ('rebecca.robles@hotmail.com',),
#  ('judith.marshall@yahoo.com',),
#  ('edward.ramirez@gmail.com',),
#  ('samantha.newman@torres.com',),
#  ('patricia.thomas@bennett.com',),
#  ('john.berger@ball.com',),
#  ('sabrina.gonzalez@patton.com',),
#  ('danielle.thompson@thomas.net',),
#  ('leslie.west@robinson.com',),
#  ('luis.hunt@hotmail.com',),
#  ('sharon.ross@sullivan-smith.org',),
#  ('sabrina.young@yahoo.com',),
#  ('jessica.rivas@davidson.com',),
#  ('michael.green@gmail.com',),
#  ('clinton.johnson@yahoo.com',),
#  ('mary.miller@martinez.info',),
#  ('billy.brown@cannon.com',),
#  ('timothy.mercado@gmail.com',),
#  ('shannon.romero@duncan-lewis.com',),
#  ('steven.long@vasquez.biz',),
#  ('jessica.hines@lewis.com',),
#  ('jennifer.macdonald@rodriguez.com',),
#  ('stephen.frazier@yahoo.com',),
#  ('kayla.price@gmail.com',),
#  ('jeffrey.lutz@williamson.net',),
#  ('sabrina.dickerson@ortiz.org',),
#  ('dennis.hale@green-perez.biz',),
#  ('katherine.ortega@hotmail.com',),
#  ('darryl.evans@hotmail.com',),
#  ('sheila.conway@yahoo.com',),
#  ('ryan.torres@walton.com',),
#  ('denise.smith@clark.org',),
#  ('mark.cervantes@yahoo.com',),
#  ('michael.adams@hotmail.com',),
#  ('larry.wallace@callahan.com',),
#  ('crystal.johnson@yahoo.com',),
#  ('kelly.bell@andrews.com',),
#  ('barbara.clarke@floyd.com',),
#  ('shannon.foley@morgan-parsons.com',),
#  ('ricardo.francis@gmail.com',),
#  ('kevin.harrison@gmail.com',),
#  ('aaron.martinez@yahoo.com',),
#  ('wendy.hughes@yahoo.com',),
#  ('michelle.warner@yahoo.com',),
#  ('jessica.wagner@coleman.net',),
#  ('vicki.sanchez@ho-campbell.com',),
#  ('calvin.gonzalez@curry.biz',),
#  ('sergio.fernandez@gmail.com',),
#  ('karen.hurley@bell.biz',),
#  ('sergio.warren@gmail.com',),
#  ('joseph.price@freeman.com',),
#  ('christina.shepherd@wang.net',),
#  ('jamie.morris@gmail.com',),
#  ('jesus.fisher@gmail.com',),
#  ('carlos.taylor@lynn.com',),
#  ('kristina.jensen@gmail.com',),
#  ('kyle.tran@williams-warner.org',),
#  ('mary.johnson@hotmail.com',),
#  ('danielle.clayton@hotmail.com',),
#  ('katie.miller@anderson.biz',),
#  ('james.olsen@hotmail.com',),
#  ('andrew.lopez@white.org',),
#  ('michelle.cooper@gmail.com',),
#  ('brenda.smith@alexander.com',),
#  ('lori.evans@martinez.info',),
#  ('sarah.allen@rodriguez.info',),
#  ('joseph.hampton@lamb.biz',),
#  ('anthony.chambers@wheeler-williams.com',),
#  ('samuel.howard@hotmail.com',),
#  ('david.jones@martinez.com',),
#  ('courtney.fuentes@yahoo.com',),
#  ('lance.rubio@anderson.com',),
#  ('richard.weber@yahoo.com',),
#  ('jeffrey.weber@avery-davis.com',),
#  ('paul.miller@stewart-raymond.info',),
#  ('benjamin.baker@gmail.com',),
#  ('tyler.barajas@cherry.biz',),
#  ('christine.tucker@hotmail.com',),
#  ('shawn.sellers@howell-martin.com',),
#  ('crystal.gutierrez@hotmail.com',),
#  ('felicia.hamilton@riley.com',),
#  ('jay.pineda@sanders.com',),
#  ('christopher.norton@hotmail.com',),
#  ('colleen.reyes@lewis.info',),
#  ('april.grant@robinson-torres.com',),
#  ('erik.bowen@martinez-russell.com',),
#  ('kimberly.thompson@taylor.net',),
#  ('taylor.hester@griffin.biz',),
#  ('david.porter@lewis-norton.com',),
#  ('colin.hall@nielsen.com',),
#  ('patrick.flores@herrera.com',),
#  ('elizabeth.bond@orr-evans.com',),
#  ('scott.ellis@payne-ortiz.com',),
#  ('gabriella.griffin@king.com',),
#  ('laurie.braun@castillo-marshall.com',),
#  ('phillip.mills@yahoo.com',),
#  ('ronald.obrien@gmail.com',),
#  ('michael.berry@ayers-collins.com',),
#  ('lori.cook@yahoo.com',),
#  ('rachel.walker@gmail.com',),
#  ('john.lutz@hotmail.com',),
#  ('lauren.wright@phillips.com',),
#  ('catherine.garcia@turner.com',),
#  ('michael.bass@gmail.com',),
#  ('kevin.collins@gmail.com',),
#  ('barbara.lane@cole-johnson.com',),
#  ('michelle.trujillo@estes.com',),
#  ('eric.horton@gmail.com',),
#  ('janet.acosta@cole-hunter.net',),
#  ('patricia.williams@yahoo.com',),
#  ('kevin.bowers@gmail.com',),
#  ('william.hart@blair-hubbard.net',),
#  ('ashley.stephens@yahoo.com',),
#  ('gregory.martinez@solis.com',),
#  ('rachel.henry@yahoo.com',),
#  ('alexandra.walters@hotmail.com',),
#  ('william.may@edwards.com',),
#  ('edgar.moses@gonzalez.com',),
#  ('robert.gonzalez@valencia.com',),
#  ('amy.lozano@gmail.com',),
#  ('joshua.montgomery@brown.info',),
#  ('amy.sawyer@juarez-hicks.biz',),
#  ('erika.white@gordon.com',),
#  ('charles.burgess@yahoo.com',),
#  ('jeffrey.murphy@yahoo.com',),
#  ('elizabeth.ford@hotmail.com',),
#  ('deanna.garza@gmail.com',),
#  ('mr..jacob@hotmail.com',),
#  ('clarence.wall@yahoo.com',),
#  ('misty.johnston@hotmail.com',),
#  ('breanna.hancock@yahoo.com',),
#  ('andrew.scott@hull-stephens.biz',),
#  ('andrew.jackson@frank.com',),
#  ('austin.rose@alvarez.com',),
#  ('jeffery.massey@roman.net',),
#  ('daniel.compton@gmail.com',),
#  ('jeffrey.smith@sellers-hart.info',),
#  ('mr..ryan@hill.org',),
#  ('lauren.nash@smith.com',),
#  ('emily.flores@norman-mendoza.com',),
#  ('tiffany.johnson@hotmail.com',),
#  ('megan.jackson@rodriguez.biz',),
#  ('dr..debra@lawrence.com',),
#  ('kelly.gaines@hotmail.com',),
#  ('michael.reeves@turner.com',),
#  ('sarah.kelley@gmail.com',),
#  ('sean.miller@yahoo.com',),
#  ('renee.knight@yahoo.com',),
#  ('brett.gardner@hotmail.com',),
#  ('scott.liu@hotmail.com',),
#  ('david.lee@gmail.com',),
#  ('vanessa.winters@gmail.com',),
#  ('mrs..christine@wilson-novak.com',),
#  ('susan.jones@gutierrez-brennan.com',),
#  ('daniel.smith@pham-shaffer.biz',),
#  ('gary.hebert@martin.biz',),
#  ('charles.barnes@gmail.com',),
#  ('kevin.martin@padilla-gray.net',),
#  ('erika.leonard@yahoo.com',),
#  ('susan.morgan@gmail.com',),
#  ('christopher.bennett@bass.com',),
#  ('christian.perez@gmail.com',),
#  ('jeffrey.miller@hooper.com',),
#  ('timothy.christensen@blankenship.com',),
#  ('sandra.peterson@gmail.com',),
#  ('craig.logan@hotmail.com',),
#  ('bradley.reeves@gmail.com',),
#  ('monica.haynes@yahoo.com',),
#  ('david.adams@carter.com',),
#  ('kristin.thompson@mendoza.net',),
#  ('diamond.miller@hotmail.com',),
#  ('brian.aguilar@yahoo.com',),
#  ('eddie.dougherty@yahoo.com',),
#  ('michele.hill@graham-chavez.net',),
#  ('john.mason@reed.com',),
#  ('william.hernandez@ibarra.com',),
#  ('katie.martin@gmail.com',),
#  ('rebecca.robinson@hotmail.com',),
#  ('mrs..michelle@gmail.com',),
#  ('cassandra.ochoa@cunningham.net',),
#  ('kaitlyn.graham@yahoo.com',),
#  ('brianna.miller@gmail.com',),
#  ('james.gallagher@green.com',),
#  ('alejandro.berry@yang.net',),
#  ('james.strong@ayers-hatfield.info',),
#  ('jo.martinez@merritt.com',),
#  ('margaret.mitchell@gmail.com',),
#  ('randall.brown@rivera.biz',),
#  ('michael.jones@yahoo.com',),
#  ('samantha.brown@anderson.com',),
#  ('john.beck@gmail.com',),
#  ('dennis.king@burns.net',),
#  ('lisa.hall@yahoo.com',),
#  ('brittany.potter@montgomery.com',),
#  ('brittany.greene@yahoo.com',),
#  ('nicole.young@gmail.com',),
#  ('john.arellano@shaw.info',),
#  ('ruben.villegas@miller.info',),
#  ('jenna.arias@garcia-hernandez.org',),
#  ('mckenzie.odom@smith.biz',),
#  ('cory.lambert@yahoo.com',),
#  ('denise.aguilar@hotmail.com',),
#  ('william.morgan@horton-murray.com',),
#  ('gregory.kent@yahoo.com',),
#  ('amanda.hoover@white-glenn.info',),
#  ('crystal.mitchell@yahoo.com',),
#  ('april.king@yahoo.com',),
#  ('jennifer.mendoza@travis.info',),
#  ('deborah.estes@wright.org',),
#  ('jared.heath@yahoo.com',),
#  ('karen.ingram@dixon.com',),
#  ('nicholas.garcia@smith-johnson.com',),
#  ('robert.ewing@miller.com',),
#  ('makayla.frye@baker.biz',),
#  ('alyssa.riley@coleman-reed.com',),
#  ('seth.king@murphy.biz',),
#  ('sandra.baird@gmail.com',),
#  ('jacob.murphy@yahoo.com',),
#  ('david.williams@gmail.com',),
#  ('manuel.acevedo@contreras-webb.org',),
#  ('deborah.jackson@martinez.info',),
#  ('paul.sanchez@yahoo.com',),
#  ('tina.hines@wolfe-gibson.biz',),
#  ('aaron.bishop@watkins.biz',),
#  ('matthew.chavez@hotmail.com',),
#  ('mike.gates@yahoo.com',),
#  ('zachary.serrano@hotmail.com',),
#  ('sharon.anderson@hotmail.com',),
#  ('melanie.clark@ayala.com',),
#  ('mrs..beth@perez.com',),
#  ('donald.murphy@cummings-alvarado.com',),
#  ('carlos.guzman@lowe.org',),
#  ('martin.gonzalez@wu-simon.info',),
#  ('amanda.hernandez@yahoo.com',),
#  ('lawrence.williams@joseph.com',),
#  ('joseph.cox@davis.com',),
#  ('david.burns@gmail.com',),
#  ('greg.moreno@dickson.com',),
#  ('william.warren@morales.com',),
#  ('william.hunter@hanson-wright.com',),
#  ('maria.kelly@johnson-williams.com',),
#  ('elizabeth.lucas@hotmail.com',),
#  ('brian.knight@hotmail.com',),
#  ('luis.silva@yahoo.com',),
#  ('shelby.barnes@miranda-wright.biz',),
#  ('barbara.garner@hotmail.com',),
#  ('ryan.logan@yahoo.com',),
#  ('carmen.macdonald@terry-pearson.com',),
#  ('theresa.stevens@ortiz.com',),
#  ('benjamin.clark@lopez.org',),
#  ('sierra.martinez@yahoo.com',),
#  ('krista.guerrero@camacho.com',),
#  ('krystal.hoffman@wright.com',),
#  ('michael.woods@robertson-jennings.net',),
#  ('thomas.mckinney@garner.com',),
#  ('mrs..amanda@yahoo.com',),
#  ('katrina.oliver@cooke.com',),
#  ('martin.morgan@gmail.com',),
#  ('jamie.willis@bennett.info',),
#  ('lisa.walton@bailey.com',),
#  ('dana.davidson@singleton-villanueva.com',),
#  ('karen.perez@anderson.org',),
#  ('katherine.ortiz@waters.biz',),
#  ('debra.white@yahoo.com',),
#  ('cheryl.moon@dorsey.com',),
#  ('raymond.jackson@hotmail.com',),
#  ('douglas.beck@collins-hogan.info',),
#  ('sarah.petty@harrison-moody.com',),
#  ('anthony.campbell@hotmail.com',),
#  ('michael.page@sweeney-sanders.org',),
#  ('cynthia.vasquez@wagner-richmond.biz',),
#  ('toni.shaw@gmail.com',),
#  ('kelli.wright@johnson.com',),
#  ('stephanie.odonnell@rodriguez.com',),
#  ('shane.sharp@parker-pratt.com',),
#  ('guy.fernandez@randolph.biz',),
#  ('samuel.poole@townsend.com',),
#  ('raymond.calhoun@houston.com',),
#  ('aaron.holmes@gmail.com',),
#  ('michelle.carter@yahoo.com',),
#  ('mark.chapman@yahoo.com',),
#  ('billy.wilcox@hotmail.com',),
#  ('sara.kelly@yahoo.com',),
#  ('kevin.wolf@gmail.com',),
#  ('jennifer.martinez@alvarez.com',),
#  ('janet.osborne@gmail.com',),
#  ('daniel.washington@powell-lopez.org',),
#  ('ryan.martin@rice.biz',),
#  ('emily.terry@ryan-barrett.com',),
#  ('jason.murillo@taylor.com',),
#  ('courtney.silva@mack.com',),
#  ('robert.smith@harrison.biz',),
#  ('jeff.rodriguez@gmail.com',),
#  ('leah.stephens@miller.net',),
#  ('joshua.brown@hotmail.com',),
#  ('jacob.brewer@hotmail.com',),
#  ('jonathan.farley@hotmail.com',),
#  ('tina.martin@lopez-turner.info',),
#  ('mallory.stone@meza.net',),
#  ('crystal.marshall@gmail.com',),
#  ('danielle.arnold@yahoo.com',),
#  ('jennifer.coleman@gmail.com',),
#  ('anthony.king@underwood-padilla.com',),
#  ('jeffery.johnson@hotmail.com',),
#  ('benjamin.gross@snyder.com',),
#  ('kenneth.ellis@martinez-watts.com',),
#  ('william.jones@tran.com',),
#  ('stephanie.morgan@bailey.biz',),
#  ('michael.young@yahoo.com',),
#  ('joel.howe@hotmail.com',),
#  ('sarah.howard@yahoo.com',),
#  ('timothy.barnett@clarke.info',),
#  ...]

# %% [markdown]
# To get address as well use UNION. UNION command we can group together the result of two SQL queries as long as they both result in the same number of columns with matching data types.

# %%
name = "Joseph Kirby' UNION SELECT address FROM users WHERE name = 'Joseph Kirby"
address_and_email = get_email(name)
print(address_and_email)
# Out:
# [('3594 Fox Ford Apt. 192 West Kristen GA 22838-8977',), ('joseph.kirby@yahoo.com',)]

# %% [markdown]
# Manually formating the query strings from given input parameters can easily open the door for SQL injections where a user is able to execute a custom query by passing it as a parameter.

# %%
def get_email_fixed(name):
    import psycopg2
    conn = psycopg2.connect("dbname=dq user=dq")
    cur = conn.cursor()
    # fix the line below
    cur.execute("SELECT email FROM users WHERE name = %s;", (name,))
    res = cur.fetchall()
    conn.close()
    return res

# %% [markdown]
# ## Prepared Statement
#
# We can use the cursor.execute() method from the psycopg2 library in order to help avoid SQL injections. However there is a direct way to do it in SQL using the PREPARE statement to form a prepared statement.
#
# `PREPARE insert_user(integer, text, text, text) AS`<br>
#     `INSERT INTO users VALUES ($1, $2, $3, $4);`
#
# When we issue this command we create a new statement named insert_user that takes in four arguments. The first argument must be of type integer and the remaining three arguments of type text because there are the types used to represent the fours columns of the users table. The SQL statement that comes after the AS keyword corresponds to the body of the prepared statement. This represents the actual query to be executed whenever we execute the statement insert_user.
#
# You can think of prepared statement of being analogous to Python functions. In the above example, it is like you are defining a function named insert_user that has four arguments. The body of the function in this case has the single line INSERT INTO users VALUES ($1, $2, $3, $4); where $1, $2, $3 and $4 represent the values of the four arguments.
#
# Note that the syntax for placeholders in the PREPARE statement is different from the one used by the cursor.execute() method from the psycopg2 Python module. In this case the placeholders are numbered $1, ..., $4 and the arguments will replace them in the order of the numbers. So the first argument will replace $1, the second $2 and so on.
#
# To execute a prepared statement we use the EXECUTE command as follows:<br>
# `EXECUTE insert_user(10002, 'bob@dataquest.io', 'Bob', '101 Fake Street');`
#
# Do not confuse the cursor.execute() method with the EXECUTE SQL command. The cursor.execute() method is a method from the cursor object of the psycopg2 Python module. It is used to issue SQL commands to the Postgres database using Python. On the other hand, the EXECUTE command is a SQL command that is used to run a prepared statement.
#
# In Postgres we can prepare and run a prepared statement as follows:

# %%
# import psycopg2
# conn = psycopg2.connect("dbname=dq user=dq")
# cur = conn.cursor()
# cur.execute("""
#     PREPARE insert_user(integer, text, text, text) AS
#         INSERT INTO users VALUES ($1, $2, $3, $4);
# """)
# cur.execute("""
#     EXECUTE insert_user(%s, %s, %s, %s);
# """, (10002, 'bob@dataquest.io', 'Bob', '101 Fake Street'))

# %% [markdown]
# Even though prepared statements protect us from SQL injections, we recommend you to pass the values using the execute method as it makes it easier to avoid syntax problems. For instance, the previous problem of having a comma in the address will still cause a error when using prepared statements.
#
# It is important for you to learn prepared statement because they are not specific to Postgres and exist in others SQL servers such as MySQL

# %% [markdown]
# When we create a prepared statement in Postgres, it is stored in a table named **pg_prepared_statements**. The prepared statements are local for the current connection meaning that:
#
# 1. They will disappear when the connection is closed.
# 2. Are only visible using the cursor from the connection with which it was created.
#
# From the documentation of prepared statements we see that the this table contains five columns. The columns contain the following information:
#
# 1. The name of the prepared statement, in this case insert_user.
# * A string containing the prepared statement itself.
# * A datetime object giving the time at which it was created.
# * The datatypes of the arguments of the prepared statement.
# * A boolean value specifying whether or not it was created with a PREPARE command.
#
# This table is mostly useful for you to be able to see the current prepared statements. We believe that in general it is important to learn Postgres internal tables to be able to get a deeper understanding of how it works.
#
# Let's practice one more time with creating a prepared statement and inspect the pg_prepared_statements table to check that it indeed appears there.

# %%
conn = psycopg2.connect("dbname=Dataquest user=postgres password=123")

# %%
cur = conn.cursor()

# %%
cur.execute("""PREPARE get_email(text) AS
                SELECT email FROM users WHERE name = $1;
""")

# %%
cur.execute("""EXECUTE get_email(%s);
""",('Anna Carter',))

# %%
anna_email = cur.fetchone()

# %%
cur.execute("SELECT * FROM pg_prepared_statements;")
print(cur.fetchall())
# Out:
# [('get_email', 'PREPARE get_email(text) AS\n                SELECT email FROM users WHERE name = $1;\n', datetime.datetime(2021, 8, 14, 22, 30, 12, 771073, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-240, name=None)), '{text}', True)]

# %% [markdown]
# **Prepared statements main purpose is to avoid SQL injections**.<br>
# However they can sometimes accelerate queries.<br>
# To analyze the speed gained from using prepared statement we performing the same query a lot of times.<br>
# When we perform a SQL query, in a high level the following steps occur:<br>
#
# <Img src="https://github.com/rhnyewale/PostgreSQL/blob/main/Images/SQL_query_parsing_rewrite_planning_execution.JPG?raw=true">
#
#
# 1. The query is parsed for correct syntax
#
# 2. If there are no syntax errors, the query is transformed into something that the SQL engine can understand and execute
#
# 3. Using the result from step 2 a query plan is created that tries to find the most efficient way to execute the query
#
# 4. The plan produced on step 3 is executed on the database
#
# In contrast, when we prepare a statement as we did before, steps 1, 2 and 3 are performed at that moment. This means that the query is ready to be executed on the database. This has two major consequences:
#
# 1. Whenever we execute a prepared statement, the query plan will already exist so it will be executed directly.
# 2. Since we don't go over a parsing step anymore, no SQL code passed as a value will ever be interpreted as SQL code thus preventing SQL injections.
#
# Let's compare the runtime of inserting all users with and without prepared statements.
#
# `import timeit`<br>
# `runtime = timeit.timeit(function_name, number=1)`
#
# function_name is the name of the function that we want to time and number is the number of times that we want to execute the function. In general, to get an estimation of the runtime we run the function several times and compute the average runtime

# %%
import timeit
import psycopg2
import csv
# function that inserts all users using a prepared statement
def prepared_insert():
    conn = psycopg2.connect("dbname=Dataquest user=postgres password=123")
    cur = conn.cursor()           
    cur.execute("""
        PREPARE insert_user(integer, text, text, text) AS
        INSERT INTO users VALUES ($1, $2, $3, $4)
    """)
    for user in users:
        cur.execute("EXECUTE insert_user(%s, %s, %s, %s)", user)
    conn.close()

# function that insert all users using a new INSERT query for each user
def regular_insert():
    conn = psycopg2.connect("dbname=Dataquest user=postgres password=123")
    cur = conn.cursor()           
    for user in users:
        cur.execute("""
            INSERT INTO users VALUES (%s, %s, %s, %s)
        """, user)
    conn.close()

# read the users into a list
users = [ ]
with open('user_accounts.csv', 'r') as file:
    next(file) # skip csv header
    reader = csv.reader(file)
    for row in reader:
        users.append(row)
# write you code here
time_prepared = timeit.timeit(prepared_insert, number=1)
time_regular = timeit.timeit(regular_insert, number=1)
print(time_prepared)
print(time_regular)
